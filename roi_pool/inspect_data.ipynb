# %%
import numpy as np
import matplotlib.pyplot as plt

from IPython.display import clear_output

# %%
from datagen import gen_image, gen_batch

clear_output()

# %%
image, label = gen_image()
image.shape, label
# Out:
# ((128, 128, 1), (0.6328125, 0.7734375))

# %%
plt.title(label)
plt.imshow(image[..., 0]);

# %%
x, y = gen_batch(fixed_size=True)
x.shape, y.shape
# Out:
# ((32, 128, 128, 1), (32, 2))

# %%
plt.figure(figsize=(20, 10))
for i in range(8):
    plt.subplot(2, 4, i+1)
    plt.title(y[i])
    plt.imshow(x[i, ..., 0])

# %%
x, y = gen_batch(fixed_size=False)
x.shape, y.shape
# Out:
# ((32, 250, 300, 1), (32, 2))

# %%
plt.figure(figsize=(20, 10))
for i in range(8):
    plt.subplot(2, 4, i+1)
    plt.title(y[i])
    plt.imshow(x[i][..., 0])
